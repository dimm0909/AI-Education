# %% [markdown]
# # BikeFlow EDA and Baseline
#
# Цель: посмотреть распределение спроса и базовый эксперимент.

# %%
import pandas as pd

df = pd.read_csv('../data/raw/hour.csv')
df.head()

# %%
df[['cnt', 'temp', 'hum', 'windspeed']].describe()
